# %% [markdown]
# # Prospective Learning: A Quick Overview
#
# Learning involves updating decision rules based on past experience to improve future performance. Probably approximately correct (PAC) learning has been
# extremely useful to develop algorithms that minimize the risk—typically defined as the expected loss—on unseen samples under certain assumptions. The assumption, that samples are independent and identically distributed (IID) within the training dataset and at test time, has served us well. But it is neither testable nor believed to be true in practice. The future is always different from the past: both distributions of data and goals of the learner may change over time. Moreover, those changes may cause the optimal hypothesis to change over time as well. Although, numerous approaches have been developed to address this issue, we still lack a first-principles framework to address problems where data distributions and goals may change over time in such a way that the optimal hypothesis is time-dependent.
#
# We have developed a theoretical framework called "Prospective Learning". Instead of data arising from an unknown probability distribution like in PAC learning, prospective learning assumes that data comes from an unknown stochastic process, that the loss considers the future, and that the optimal hypothesis may change over time. A prospective learner uses samples received up to some time $t \in \mathbb{N}$ to output an infinite sequence of predictors, which is uses for making predictions on data at all future times $t' > t$. A prospective learner minimizes the expected cumulative risk of the future using past data. To properly define such a learner, let's first define several key ingredients.
#
# ### Definitions
#
# 1. **Data**: $z_t = (x_t, y_t)$ is the datum at time $t$. Data is drawn from a stochastic process $Z \equiv (Z_t)_{t \in \mathbb{N}}$. Past data $z_{\leq t} \equiv (z_1, \dots, z_t)$, future data $z_{> t} \equiv (z_{t+1}, \dots)$
#
# 2. **Hypothesis Class**: A prospective learner selects an infinite sequence of hypotheses $h \equiv (h_1,\dots,h_t,h_{t+1},\dots) \in \mathcal{H}$
#
# 3. **Learner**: A map from past data $z_{\leq t}$ to a $h \in \mathcal{H}$
#
# 4. **Prospective Loss**: Future loss incurred by a hypothesis $h$
#
# $$
#     \bar \ell_t(h, Z) = \limsup_{\tau \to \infty} \frac{1}{\tau} \sum_{s=t+1}^{t+\tau} \ell (s, h_s(X_s), Y_s)
# $$
#
# 5. **Prospective Risk**: Prospective risk at time $t$ is the expected future loss
#
# $$
#     R_t(h)
#     = \mathbb{E} [ \bar \ell_t(h,Z) \mid z_{\leq  t} ]
#     = \int \bar \ell_t(h,Z) \ \mathrm{d} \mathbb{P}_{Z \mid z_{\leq t}}
# $$
#
# 6. **Prospective Bayes Risk**: Minimum achievable prospective risk by any learner that observes past data $z_{\leq t}$
#
# $$
#     R_t^* = \inf_{h\in \sigma(Z_{\leq t})}  R_t(h)
# $$
#
# The following schematic illustration depicts a prospective learner.
#
# <div style="text-align: center;">
#     <img src="../assets/cartoon.jpg" alt="Alt text" style="width: 30%;"/>
# </div>
#
# ### A simple data generating process
#
# Suppose there are two binary classification problems (“tasks”) where the input is one-dimensional. Inputs for both tasks are drawn from a uniform distribution
# on the set $[−2, −1] \cup [1, 2]$. Ground-truth labels correspond to the sign of the input for Task 1, and the negative of the sign of the input for Task 2. Now consider a stochastic process where the task periodically alternates between task 1 and task 2, with period $= 20$.
#
# <div style="text-align: center;">
#     <img src="../assets/dp.jpg" alt="Alt text" style="width: 50%;"/>
# </div>

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, Dataset, TensorDataset
from dataclasses import dataclass

@dataclass
class ProcessConfig:
    """configure the data generating process"""
    period: int = 40
    seq_len: int = 10000
    num_seeds: int = 3 

class DataGeneratingProcess:
    """data generating process"""
    def __init__(self, cfg):
        self.seq_len = cfg.seq_len
        self.num_seeds = cfg.num_seeds
        self.period = cfg.period

    def generate_data(self):
        """generate data sequences over the specified number of seeds"""
        xseq, yseq, taskseq = [], [], []
        tseq = []
        for _ in range(self.num_seeds):
            dat = self.generate_sequence(np.random.randint(0, 10000))
            xseq.append(dat[0])
            yseq.append(dat[1])
            taskseq.append(dat[2])
            tseq.append(np.arange(self.seq_len))

        xseq = np.array(xseq)
        yseq = np.array(yseq)
        tseq = np.array(tseq)
        taskseq = np.array(taskseq)

        self.data = {'x': xseq,
                     'y': yseq,
                     't': tseq,
                     'task': taskseq}

    def generate_sequence(self, seed):
        """generate a sequence of data"""
        np.random.seed(seed)

        # generate samples from U[-2, -1] union U[1, 2]
        x1 = np.random.uniform(-2, -1, self.seq_len)
        x2 = np.random.uniform(1, 2, self.seq_len)
        mask = np.random.choice([0, 1], p=[0.5, 0.5], size=self.seq_len)
        Xdat = x1 * mask + x2 * (1 - mask)

        # create labels
        T = self.period
        tind = np.array((np.arange(0, self.seq_len) % T) < (T // 2))
        tind = tind.astype(int)
        ind = np.where(tind == 1)[0]

        Ydat = Xdat > 0
        Ydat[ind] = Xdat[ind] < 0
        Ydat = Ydat.astype(int)

        Xdat = Xdat.reshape(-1, 1)

        return Xdat, Ydat, tind
    
    def generate_at_time(self, t, num_samples):
        """generate a test sample of data (x, y) ~ p_t from the marginal 
        of the process at time t. This is used to evaluate the instantaneous
        loss of the predictor
        """
        # Generate samples from U[-2, -1] union U[1, 2]
        x1 = np.random.uniform(-2, -1, num_samples)
        x2 = np.random.uniform(1, 2, num_samples)
        mask = np.random.choice([0, 1], p=[0.5, 0.5], size=num_samples)
        Xdat = x1 * mask + x2 * (1 - mask)

        # create labels
        T = self.period
        if (t % T) < (T // 2):
            Ydat = Xdat < 0
        else:
            Ydat = Xdat > 0

        Xdat = Xdat.reshape(-1, 1)
        tdat = t * np.ones(num_samples)

        x = torch.from_numpy(Xdat).float()
        y = torch.from_numpy(Ydat).long()
        t = torch.from_numpy(tdat).float()
        return x, y, t
    
class SyntheticDataset(Dataset):
    """Form the torch dataset"""
    def __init__(self, data, idx, run_id, test, past=None):
        self.x = torch.from_numpy(data['x']).float()
        self.y = torch.from_numpy(data['y']).long()
        self.t = torch.from_numpy(data['t']).float()

        if test:
            # Use data from time 'idx' onwards for testing
            self.x = self.x[run_id, idx:]
            self.y = self.y[run_id, idx:]
            self.t = self.t[run_id, idx:]
        else:
            if past is None:
                #  # Use data up to time 'idx' onwards for training (full history)
                self.x = self.x[run_id, :idx]
                self.y = self.y[run_id, :idx]
                self.t = self.t[run_id, :idx]
            else:
                # Use the most recent past data up to time 'idx' onwards for training (partial history)
                self.x = self.x[run_id, idx-past:idx]
                self.y = self.y[run_id, idx-past:idx]
                self.t = self.t[run_id, idx-past:idx]

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        x = self.x[idx]
        y = self.y[idx]
        t = self.t[idx]
        return x, y, t

# %% [markdown]
# ### A simple prospective learner
#
# Theorem 1 of our works states that a learner that minimizes empirical prospective risk over a class consisting of infinite sequence of hypotheses is a strong prospective learner. We denote this learner by "prospective empirical risk minimizer" or "prospective ERM". In other words, we have to minimize the prospective risk over a sequence of predictors indexed by time. We construct a sequence of predictors by incorporating time as an additional input to a multi-layer perceptron (MLP). For frequencies $\omega_i = \pi/i$ for $i = 1, \dots, d/2$, we obtain a $d$-dimensional embedding of time $t$ as $\varphi(t) = (\sin(\omega_1 t), \dots, \sin(\omega_{d/2} t), \cos(\omega_1 t), \dots, \cos(\omega_{d/2} t))$. A predictor $h_t(\cdot)$ uses a MLP that takes as input, an embedding of time $\varphi(s)$, and the input $x_s$ to predict the output $y_s$ for any time $s \in \mathbb{N}$. Using
# such an embedding of time is useful in prospective learning because, then, one need not explicitly maintain the infinite sequence of predictors $h \equiv (h_1, \dots)$.
#
# <div style="text-align: center;">
#     <img src="../assets/perm.jpg" alt="Alt text" style="width: 25%;"/>
# </div>
#
# We implement this simple prospective learner as follows. Note that in the code snippet below, write a simple MLP architecture and equip it with an option to include time
# as an input.

# %%
import torch.nn as nn

class TimeEmbedding(nn.Module):
    """form the time-embedding"""
    def __init__(self, tdim=10):
        super(TimeEmbedding, self).__init__()
        self.freqs = (2 * np.pi) / torch.arange(2, tdim + 1, 2).unsqueeze(0)

    def forward(self, t):
        sin_emb = torch.sin(self.freqs.to(t.device) * t)
        cos_emb = torch.cos(self.freqs.to(t.device) * t)
        return torch.cat([sin_emb, cos_emb], dim=-1)
    
class MLP(nn.Module):
    """a simple MLP architecture for implementing both vanilla-MLP and
    prospective-MLP
    """
    def __init__(self, in_dim=1, out_dim=2, hidden_dim=32, tdim=50, prospective=False):
        super(MLP, self).__init__()
        self.prospective = prospective
        if prospective:
            self.time_embed = TimeEmbedding(tdim=tdim)
            self.fc1 = nn.Linear(in_dim + tdim, hidden_dim)
        else:
            self.fc1 = nn.Linear(in_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, out_dim)

    def forward(self, x, t):
        if self.prospective:
            t = self.time_embed(t.unsqueeze(-1))
            x = torch.cat([x, t], dim=-1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# We use the zero-one error to calculate prospective risk. In this notebook, we only consider several differen learners including follow-the-leader (FTL), online gradient descent (OGD), Bayesian gradient descent (BGD), and prosepctive learner. FTL outputs a single fixed predictor over all times after being trained on all the past data. In OGD we keep finetuining a fixed predictor at each time using the most recent past data. BGD is a task agnostic continual learner that aims to prevent catastrophic forgetting. Finally, prospective learner outputs a time-varying predictor that consumes both the time and the input.
#
# We generate a sequence of 10000 samples from the data generating process. The learners are trained on the data from the first $t$ time steps ($z_{\leq t}$). Next we compute the instantaneous loss (loss of the predictor at time $t$) and prospective loss (average loss of the predictor over the future samples $z_{>t}$). We repeat this procedure over 3 random seeds to obtain estimates for instantaneous risk and prospective risk at time $t$.
#
# Let's write a trainer class to train our models, and several helper functions to set random seeds and obtain data loaders.

# %%
import random
import sys
sys.path.append('../')
from deep_nets.utils.bgd import BGD

def set_seed(acorn):
    """set random seed"""
    random.seed(acorn)
    np.random.seed(acorn)
    torch.manual_seed(acorn)
    torch.cuda.manual_seed(acorn)
    torch.cuda.manual_seed_all(acorn)

def get_dataloaders(dp, t, seed, past=None):
    """obtain the dataloaders"""
    if past:
        if t < 16:
            train_dataset = SyntheticDataset(dp.data, t, seed, test=False, past=None)
        else:
            train_dataset = SyntheticDataset(dp.data, t, seed, test=False, past=past)
    else:
        train_dataset = SyntheticDataset(dp.data, t, seed, test=False, past=None)
    test_dataset = SyntheticDataset(dp.data, t, seed, test=True)
    ttest_dataset = TensorDataset(*dp.generate_at_time(t, 500))

    if t < 32:
        bs = 2
    else:
        if past:
            if t < 8: bs = 2
            else: bs = 8
        else:
            bs = 32
            
    trainloader = DataLoader(
        train_dataset,
        batch_size=bs,
        shuffle=True,
        drop_last=True
    )
    testloader = DataLoader(
        test_dataset, 
        batch_size=100,
        shuffle=False
    )
    ttestloader = DataLoader(
        ttest_dataset, 
        batch_size=100,
        shuffle=False
    )
    return trainloader, testloader, ttestloader


def get_optimizer(model, bgd=False):
    """Obtain the appropriate optimizer"""
    if bgd:
        params = [{'params': [p]} for p in model.parameters()]
        optimizer = BGD(params, std_init=0.01)
    else:
        optimizer = torch.optim.SGD(
            model.parameters(), 
            lr=0.1,
            momentum=0.9, 
            nesterov=True,
            weight_decay=0.00001
        )
    return optimizer

class Trainer:
    """trainer class for the models"""
    def __init__(self, model, train_loader, test_loader, ttest_loader, optimizer, device, verbose=False):
        self.model = model
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.ttest_loader = ttest_loader

        self.criterion = nn.CrossEntropyLoss()
        self.optimizer = optimizer

        self.device = device
        self.verbose = verbose

        self.bgd = True if optimizer.__class__.__name__ == 'BGD' else False

    def train_one_epoch(self):
        self.model.train()
        total_loss = 0.0
        
        for batch in self.train_loader:
            batch = [b.to(self.device) for b in batch]
            x, y, t = batch

            if self.bgd:
                bs = x.size(0)
                for mc_iter in range(10):
                    self.optimizer.randomize_weights()
                    outputs = self.model(x, t)
                    loss = self.criterion(outputs.squeeze(), y)
                    self.optimizer.zero_grad()
                    loss.backward()
                    self.optimizer.aggregate_grads(bs)
            else:
                outputs = self.model(x, t)
                loss = self.criterion(outputs.squeeze(), y)
                self.optimizer.zero_grad()  
                loss.backward()  

            self.optimizer.step() 
            total_loss += loss.item()

        return total_loss / len(self.train_loader)

    def evaluate(self, model=None):
        if model:
            self.model = model
        self.model.eval()
        perrs = []
        with torch.no_grad():
            for batch in self.test_loader:
                batch = [b.to(self.device) for b in batch]
                x, y, t = batch
                logits = self.model(x, t)
                probs = torch.softmax(logits, dim=1)
                err = (probs.argmax(dim=1) != y).float()
                perrs.append(err.cpu().numpy())
        perrs = np.concatenate(perrs)
        ploss = perrs.mean()

        errs = []
        with torch.no_grad():
            for batch in self.ttest_loader:
                batch = [b.to(self.device) for b in batch]
                x, y, t = batch
                logits = self.model(x, t)
                probs = torch.softmax(logits, dim=1)
                err = (probs.argmax(dim=1) != y).float()
                errs.append(err.cpu().numpy())
        iloss = np.concatenate(errs).mean()
        return iloss, ploss, perrs

    def train(self, num_epochs):
        for epoch in range(num_epochs):
            train_loss = self.train_one_epoch()
            if self.verbose:
                print(f'Epoch [{epoch + 1}/{num_epochs}], '
                    f'Train Loss: {train_loss:.4f}, ')
        print(f"training loss at last epoch: {train_loss:.3f}")

# %% [markdown]
# We have all the ingredients to run our experiment now. The code snippet below will train the
# predictors for at a series of $t$ values and evaluate both prospective and instantaneous risks.
# It takes about 16 mins to run this cell on a CPU.

# %%
# configure and obtain the data generating process
period = 40
cfg = ProcessConfig(
    period=period,
    seq_len=10000,
    num_seeds=3,
)
dp = DataGeneratingProcess(cfg)
dp.generate_data()

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# learners being considered
methods = ["FTL", "Prospective", "OGD", "BGD"]

t_list = np.arange(20, 1200, 1) # list of time steps 

instant_risk = {} # store instant risk for each algorithm
prospective_risk = {} # store prospective risk for each algorithm

for method in methods:
    instant_losses = []
    prospective_losses = []
    for seed in range(cfg.num_seeds):
        print(f"seed = {seed}")
        acorn = seed * 1000 + 1996
        set_seed(acorn)

        online = ("OGD" in method) or ("BGD" in method)

        if online:
            model = MLP(prospective=False)
            model.to(device)
            optimizer = get_optimizer(model, bgd=True if "BGD" in method else False)

        iloss_list = []
        ploss_list = []
        
        for t in t_list:
            print(f"time t = {t}")

            if online:
                is_first_step = True if t == t_list[0] else False
                trainloader, testloader, ttestloader = get_dataloaders(dp, t, seed, past=None if is_first_step else 16)
                trainer = Trainer(model, trainloader, testloader, ttestloader, optimizer, device)
                if t > 2:
                    trainer.train(num_epochs=100 if is_first_step else 1)
            else:
                trainloader, testloader, ttestloader = get_dataloaders(dp, t, seed)
                prospective = True if "Prospective" in method else False
                model = MLP(prospective=prospective)
                model.to(device)
                optimizer = get_optimizer(model)
                trainer = Trainer(model, trainloader, testloader, ttestloader, optimizer, device)
                if t > 2:
                    trainer.train(num_epochs=100)
                
            iloss, ploss, _ = trainer.evaluate()
            iloss_list.append(iloss)
            ploss_list.append(ploss)

        instant_losses.append(iloss_list)
        prospective_losses.append(ploss_list)

    instant_risk[method] = np.stack(instant_losses).mean(axis=0)
    prospective_risk[method] = np.stack(prospective_losses).mean(axis=0)
# Out:
# seed = 0
# time t = 20
# training loss at last epoch: 0.000
# time t = 21
# training loss at last epoch: 0.091
# time t = 22
# training loss at last epoch: 0.205
# time t = 23
# training loss at last epoch: 0.324
# time t = 24
# training loss at last epoch: 0.409
# time t = 25
# training loss at last epoch: 0.465
# time t = 26
# training loss at last epoch: 0.711
# time t = 27
# training loss at last epoch: 0.639
# time t = 28
# training loss at last epoch: 0.736
# time t = 29
# training loss at last epoch: 0.708
# time t = 30
# training loss at last epoch: 0.667
# time t = 31
# training loss at last epoch: 0.658
# time t = 32
# training loss at last epoch: 0.541
# time t = 33
# training loss at last epoch: 0.494
# time t = 34
# training loss at last epoch: 0.609
# time t = 35
# training loss at last epoch: 0.626
# time t = 36
# training loss at last epoch: 0.619
# time t = 37
# training loss at last epoch: 0.619
# time t = 38
# training loss at last epoch: 0.653
# time t = 39
# training loss at last epoch: 0.632
# time t = 40
# training loss at last epoch: 0.614
# time t = 41
# training loss at last epoch: 0.698
# time t = 42
# training loss at last epoch: 0.628
# time t = 43
# training loss at last epoch: 0.667
# time t = 44
# training loss at last epoch: 0.660
# time t = 45
# training loss at last epoch: 0.663
# time t = 46
# training loss at last epoch: 0.713
# time t = 47
# training loss at last epoch: 0.659
# time t = 48
# training loss at last epoch: 0.639
# time t = 49
# training loss at last epoch: 0.664
# time t = 50
# training loss at last epoch: 0.701
# time t = 51
# training loss at last epoch: 0.661
# time t = 52
# training loss at last epoch: 0.607
# time t = 53
# training loss at last epoch: 0.610
# time t = 54
# training loss at last epoch: 0.669
# time t = 55
# training loss at last epoch: 0.595
# time t = 56
# training loss at last epoch: 0.607
# time t = 57
# training loss at last epoch: 0.636
# time t = 58
# training loss at last epoch: 0.570
# time t = 59
# training loss at last epoch: 0.539
# time t = 60
# training loss at last epoch: 0.580
# time t = 61
# training loss at last epoch: 0.604
# time t = 62
# training loss at last epoch: 0.544
# time t = 63
# training loss at last epoch: 0.680
# time t = 64
# training loss at last epoch: 0.636
# time t = 65
# training loss at last epoch: 0.663
# time t = 66
# training loss at last epoch: 0.688
# time t = 67
# training loss at last epoch: 0.666
# time t = 68
# training loss at last epoch: 0.666
# time t = 69
# training loss at last epoch: 0.670
# time t = 70
# training loss at last epoch: 0.678
# time t = 71
# training loss at last epoch: 0.660
# time t = 72
# training loss at last epoch: 0.677
# time t = 73
# training loss at last epoch: 0.674
# time t = 74
# training loss at last epoch: 0.674
# time t = 75
# training loss at last epoch: 0.690
# time t = 76
# training loss at last epoch: 0.685
# time t = 77
# training loss at last epoch: 0.688
# time t = 78
# training loss at last epoch: 0.661
# time t = 79
# training loss at last epoch: 0.682
# time t = 80
# training loss at last epoch: 0.693
# time t = 81
# training loss at last epoch: 0.689
# time t = 82
# training loss at last epoch: 0.671
# time t = 83
# training loss at last epoch: 0.690
# time t = 84
# training loss at last epoch: 0.700
# time t = 85
# training loss at last epoch: 0.674
# time t = 86
# training loss at last epoch: 0.690
# time t = 87
# training loss at last epoch: 0.671
# time t = 88
# training loss at last epoch: 0.701
# time t = 89
# training loss at last epoch: 0.687
# time t = 90
# training loss at last epoch: 0.649
# time t = 91
# training loss at last epoch: 0.681
# time t = 92
# training loss at last epoch: 0.680
# time t = 93
# training loss at last epoch: 0.716
# time t = 94
# training loss at last epoch: 0.699
# time t = 95
# training loss at last epoch: 0.669
# time t = 96
# training loss at last epoch: 0.685
# time t = 97
# training loss at last epoch: 0.681
# time t = 98
# training loss at last epoch: 0.678
# time t = 99
# training loss at last epoch: 0.686
# time t = 100
# training loss at last epoch: 0.678
# time t = 101
# training loss at last epoch: 0.676
# time t = 102
# training loss at last epoch: 0.683
# time t = 103
# training loss at last epoch: 0.676
# time t = 104
# training loss at last epoch: 0.679
# time t = 105
# training loss at last epoch: 0.676
# time t = 106
# training loss at last epoch: 0.675
# time t = 107
# training loss at last epoch: 0.698
# time t = 108
# training loss at last epoch: 0.691
# time t = 109
# training loss at last epoch: 0.681
# time t = 110
# training loss at last epoch: 0.686
# time t = 111
# training loss at last epoch: 0.698
# time t = 112
# training loss at last epoch: 0.694
# time t = 113
# training loss at last epoch: 0.686
# time t = 114
# training loss at last epoch: 0.693
# time t = 115
# training loss at last epoch: 0.703
# time t = 116
# training loss at last epoch: 0.696
# time t = 117
# training loss at last epoch: 0.692
# time t = 118
# training loss at last epoch: 0.693
# time t = 119
# training loss at last epoch: 0.696
# time t = 120
# training loss at last epoch: 0.693
# time t = 121
# training loss at last epoch: 0.692
# time t = 122
# training loss at last epoch: 0.696
# time t = 123
# training loss at last epoch: 0.698
# time t = 124
# training loss at last epoch: 0.695
# time t = 125
# training loss at last epoch: 0.723
# time t = 126
# training loss at last epoch: 0.690
# time t = 127
# training loss at last epoch: 0.688
# time t = 128
# training loss at last epoch: 0.692
# time t = 129
# training loss at last epoch: 0.690
# time t = 130
# training loss at last epoch: 0.699
# time t = 131
# training loss at last epoch: 0.691
# time t = 132
# training loss at last epoch: 0.688
# time t = 133
# training loss at last epoch: 0.694
# time t = 134
# training loss at last epoch: 0.689
# time t = 135
# training loss at last epoch: 0.695
# time t = 136
# training loss at last epoch: 0.688
# time t = 137
# training loss at last epoch: 0.689
# time t = 138
# training loss at last epoch: 0.684
# time t = 139
# training loss at last epoch: 0.693
# time t = 140
# training loss at last epoch: 0.683
# time t = 141
# training loss at last epoch: 0.681
# time t = 142
# training loss at last epoch: 0.695
# time t = 143
# training loss at last epoch: 0.681
# time t = 144
# training loss at last epoch: 0.688
# time t = 145
# training loss at last epoch: 0.681
# time t = 146
# training loss at last epoch: 0.691
# time t = 147
# training loss at last epoch: 0.685
# time t = 148
# training loss at last epoch: 0.692
# time t = 149
# training loss at last epoch: 0.697
# time t = 150
# training loss at last epoch: 0.698
# time t = 151
# training loss at last epoch: 0.690
# time t = 152
# training loss at last epoch: 0.691
# time t = 153
# training loss at last epoch: 0.691
# time t = 154
# training loss at last epoch: 0.691
# time t = 155
# training loss at last epoch: 0.700
# time t = 156
# training loss at last epoch: 0.690
# time t = 157
# training loss at last epoch: 0.696
# time t = 158
# training loss at last epoch: 0.692
# time t = 159
# training loss at last epoch: 0.695
# time t = 160
# training loss at last epoch: 0.693
# time t = 161
# training loss at last epoch: 0.695
# time t = 162
# training loss at last epoch: 0.697
# time t = 163
# training loss at last epoch: 0.700
# time t = 164
# training loss at last epoch: 0.694
# time t = 165
# training loss at last epoch: 0.694
# time t = 166
# training loss at last epoch: 0.695
# time t = 167
# training loss at last epoch: 0.692
# time t = 168
# training loss at last epoch: 0.694
# time t = 169
# training loss at last epoch: 0.696
# time t = 170
# training loss at last epoch: 0.697
# time t = 171
# training loss at last epoch: 0.697
# time t = 172
# training loss at last epoch: 0.693
# time t = 173
# training loss at last epoch: 0.692
# time t = 174
# training loss at last epoch: 0.693
# time t = 175
# training loss at last epoch: 0.699
# time t = 176
# training loss at last epoch: 0.701
# time t = 177
# training loss at last epoch: 0.688
# time t = 178
# training loss at last epoch: 0.692
# time t = 179
# training loss at last epoch: 0.692
# time t = 180
# training loss at last epoch: 0.691
# time t = 181
# training loss at last epoch: 0.686
# time t = 182
# training loss at last epoch: 0.690
# time t = 183
# training loss at last epoch: 0.694
# time t = 184
# training loss at last epoch: 0.694
# time t = 185
# training loss at last epoch: 0.691
# time t = 186
# training loss at last epoch: 0.691
# time t = 187
# training loss at last epoch: 0.694
# time t = 188
# training loss at last epoch: 0.698
# time t = 189
# training loss at last epoch: 0.689
# time t = 190
# training loss at last epoch: 0.690
# time t = 191
# training loss at last epoch: 0.687
# time t = 192
# training loss at last epoch: 0.692
# time t = 193
# training loss at last epoch: 0.692
# time t = 194
# training loss at last epoch: 0.691
# time t = 195
# training loss at last epoch: 0.695
# time t = 196
# training loss at last epoch: 0.693
# time t = 197
# training loss at last epoch: 0.692
# time t = 198
# training loss at last epoch: 0.694
# time t = 199
# training loss at last epoch: 0.696
# time t = 200
# training loss at last epoch: 0.698
# time t = 201
# training loss at last epoch: 0.695
# time t = 202
# training loss at last epoch: 0.690
# time t = 203
# training loss at last epoch: 0.689
# time t = 204
# training loss at last epoch: 0.691
# time t = 205
# training loss at last epoch: 0.697
# time t = 206
# training loss at last epoch: 0.692
# time t = 207
# training loss at last epoch: 0.692
# time t = 208
# training loss at last epoch: 0.693
# time t = 209
# training loss at last epoch: 0.695
# time t = 210
# training loss at last epoch: 0.694
# time t = 211
# training loss at last epoch: 0.689
# time t = 212
# training loss at last epoch: 0.692
# time t = 213
# training loss at last epoch: 0.689
# time t = 214
# training loss at last epoch: 0.687
# time t = 215
# training loss at last epoch: 0.692
# time t = 216
# training loss at last epoch: 0.683
# time t = 217
# training loss at last epoch: 0.688
# time t = 218
# training loss at last epoch: 0.689
# time t = 219
# training loss at last epoch: 0.691
# time t = 220
# training loss at last epoch: 0.692
# time t = 221
# training loss at last epoch: 0.689
# time t = 222
# training loss at last epoch: 0.696
# time t = 223
# training loss at last epoch: 0.695
# time t = 224
# training loss at last epoch: 0.690
# time t = 225
# training loss at last epoch: 0.688
# time t = 226
# training loss at last epoch: 0.693
# time t = 227
# training loss at last epoch: 0.689
# time t = 228
# training loss at last epoch: 0.691
# time t = 229
# training loss at last epoch: 0.690
# time t = 230
# training loss at last epoch: 0.689
# time t = 231
# training loss at last epoch: 0.694
# time t = 232
# training loss at last epoch: 0.696
# time t = 233
# training loss at last epoch: 0.690
# time t = 234
# training loss at last epoch: 0.691
# time t = 235
# training loss at last epoch: 0.698
# time t = 236
# training loss at last epoch: 0.689
# time t = 237
# training loss at last epoch: 0.690
# time t = 238
# training loss at last epoch: 0.690
# time t = 239
# training loss at last epoch: 0.693
# time t = 240
# training loss at last epoch: 0.691
# time t = 241
# training loss at last epoch: 0.690
# time t = 242
# training loss at last epoch: 0.692
# time t = 243
# training loss at last epoch: 0.691
# time t = 244
# training loss at last epoch: 0.689
# time t = 245
# training loss at last epoch: 0.688
# time t = 246
# training loss at last epoch: 0.692
# time t = 247
# training loss at last epoch: 0.690
# time t = 248
# training loss at last epoch: 0.694
# time t = 249
# training loss at last epoch: 0.692
# time t = 250
# training loss at last epoch: 0.691
# time t = 251
# training loss at last epoch: 0.692
# time t = 252
# training loss at last epoch: 0.689
# time t = 253
# training loss at last epoch: 0.689
# time t = 254
# training loss at last epoch: 0.689
# time t = 255
# training loss at last epoch: 0.685
# time t = 256
# training loss at last epoch: 0.691
# time t = 257
# training loss at last epoch: 0.690
# time t = 258
# training loss at last epoch: 0.690
# time t = 259
# training loss at last epoch: 0.690
# time t = 260
# training loss at last epoch: 0.697
# time t = 261
# training loss at last epoch: 0.691
# time t = 262
# training loss at last epoch: 0.696
# time t = 263
# training loss at last epoch: 0.690
# time t = 264
# training loss at last epoch: 0.693
# time t = 265
# training loss at last epoch: 0.690
# time t = 266
# training loss at last epoch: 0.693
# time t = 267
# training loss at last epoch: 0.692
# time t = 268
# training loss at last epoch: 0.697
# time t = 269
# training loss at last epoch: 0.691
# time t = 270
# training loss at last epoch: 0.691
# time t = 271
# training loss at last epoch: 0.692
# time t = 272
# training loss at last epoch: 0.689
# time t = 273
# training loss at last epoch: 0.690
# time t = 274
# training loss at last epoch: 0.692
# time t = 275
# training loss at last epoch: 0.694
# time t = 276
# training loss at last epoch: 0.691
# time t = 277
# training loss at last epoch: 0.694
# time t = 278
# training loss at last epoch: 0.703
# time t = 279
# training loss at last epoch: 0.696
# time t = 280
# training loss at last epoch: 0.688
# time t = 281
# training loss at last epoch: 0.696
# time t = 282
# training loss at last epoch: 0.700
# time t = 283
# training loss at last epoch: 0.695
# time t = 284
# training loss at last epoch: 0.691
# time t = 285
# training loss at last epoch: 0.692
# time t = 286
# training loss at last epoch: 0.697
# time t = 287
# training loss at last epoch: 0.688
# time t = 288
# training loss at last epoch: 0.690
# time t = 289
# training loss at last epoch: 0.692
# time t = 290
# training loss at last epoch: 0.693
# time t = 291
# training loss at last epoch: 0.699
# time t = 292
# training loss at last epoch: 0.691
# time t = 293
# training loss at last epoch: 0.692
# time t = 294
# training loss at last epoch: 0.691
# time t = 295
# training loss at last epoch: 0.691
# time t = 296
# training loss at last epoch: 0.692
# time t = 297
# training loss at last epoch: 0.691
# time t = 298
# training loss at last epoch: 0.692
# time t = 299
# training loss at last epoch: 0.687
# time t = 300
# training loss at last epoch: 0.690
# time t = 301
# training loss at last epoch: 0.696
# time t = 302
# training loss at last epoch: 0.691
# time t = 303
# training loss at last epoch: 0.689
# time t = 304
# training loss at last epoch: 0.696
# time t = 305
# training loss at last epoch: 0.693
# time t = 306
# training loss at last epoch: 0.694
# time t = 307
# training loss at last epoch: 0.691
# time t = 308
# training loss at last epoch: 0.695
# time t = 309
# training loss at last epoch: 0.698
# time t = 310
# training loss at last epoch: 0.692
# time t = 311
# training loss at last epoch: 0.698
# time t = 312
# training loss at last epoch: 0.691
# time t = 313
# training loss at last epoch: 0.697
# time t = 314
# training loss at last epoch: 0.691
# time t = 315
# training loss at last epoch: 0.696
# time t = 316
# training loss at last epoch: 0.694
# time t = 317
# training loss at last epoch: 0.691
# time t = 318
# training loss at last epoch: 0.700
# time t = 319
# training loss at last epoch: 0.692
# time t = 320
# training loss at last epoch: 0.692
# time t = 321
# training loss at last epoch: 0.690
# time t = 322
# training loss at last epoch: 0.690
# time t = 323
# training loss at last epoch: 0.694
# time t = 324
# training loss at last epoch: 0.699
# time t = 325
# training loss at last epoch: 0.695
# time t = 326
# training loss at last epoch: 0.694
# time t = 327
# training loss at last epoch: 0.690
# time t = 328
# training loss at last epoch: 0.692
# time t = 329
# training loss at last epoch: 0.692
# time t = 330
# training loss at last epoch: 0.691
# time t = 331
# training loss at last epoch: 0.693
# time t = 332
# training loss at last epoch: 0.693
# time t = 333
# training loss at last epoch: 0.692
# time t = 334
# training loss at last epoch: 0.694
# time t = 335
# training loss at last epoch: 0.690
# time t = 336
# training loss at last epoch: 0.695
# time t = 337
# training loss at last epoch: 0.693
# time t = 338
# training loss at last epoch: 0.695
# time t = 339
# training loss at last epoch: 0.695
# time t = 340
# training loss at last epoch: 0.690
# time t = 341
# training loss at last epoch: 0.693
# time t = 342
# training loss at last epoch: 0.690
# time t = 343
# training loss at last epoch: 0.690
# time t = 344
# training loss at last epoch: 0.693
# time t = 345
# training loss at last epoch: 0.694
# time t = 346
# training loss at last epoch: 0.692
# time t = 347
# training loss at last epoch: 0.693
# time t = 348
# training loss at last epoch: 0.695
# time t = 349
# training loss at last epoch: 0.698
# time t = 350
# training loss at last epoch: 0.688
# time t = 351
# training loss at last epoch: 0.693
# time t = 352
# training loss at last epoch: 0.699
# time t = 353
# training loss at last epoch: 0.698
# time t = 354
# training loss at last epoch: 0.698
# time t = 355
# training loss at last epoch: 0.692
# time t = 356
# training loss at last epoch: 0.692
# time t = 357
# training loss at last epoch: 0.694
# time t = 358
# training loss at last epoch: 0.695
# time t = 359
# training loss at last epoch: 0.691
# time t = 360
# training loss at last epoch: 0.694
# time t = 361
# training loss at last epoch: 0.693
# time t = 362
# training loss at last epoch: 0.692
# time t = 363
# training loss at last epoch: 0.694
# time t = 364
# training loss at last epoch: 0.691
# time t = 365
# training loss at last epoch: 0.692
# time t = 366
# training loss at last epoch: 0.692
# time t = 367
# training loss at last epoch: 0.699
# time t = 368
# training loss at last epoch: 0.694
# time t = 369
# training loss at last epoch: 0.697
# time t = 370
# training loss at last epoch: 0.693
# time t = 371
# training loss at last epoch: 0.694
# time t = 372
# training loss at last epoch: 0.695
# time t = 373
# training loss at last epoch: 0.694
# time t = 374
# training loss at last epoch: 0.694
# time t = 375
# training loss at last epoch: 0.697
# time t = 376
# training loss at last epoch: 0.693
# time t = 377
# training loss at last epoch: 0.693
# time t = 378
# training loss at last epoch: 0.691
# time t = 379
# training loss at last epoch: 0.694
# time t = 380
# training loss at last epoch: 0.739
# time t = 994
# training loss at last epoch: 0.727
# time t = 995
# training loss at last epoch: 0.731
# time t = 996
# training loss at last epoch: 0.742
# time t = 997
# training loss at last epoch: 0.740
# time t = 998
# training loss at last epoch: 0.736
# time t = 999
# training loss at last epoch: 0.725
# time t = 1000
# training loss at last epoch: 0.720
# time t = 1001
# training loss at last epoch: 0.724
# time t = 1002
# training loss at last epoch: 0.713
# time t = 1003
# training loss at last epoch: 0.692
# time t = 1004
# training loss at last epoch: 0.695
# time t = 1005
# training loss at last epoch: 0.708
# time t = 1006
# training loss at last epoch: 0.698
# time t = 1007
# training loss at last epoch: 0.699
# time t = 1008
# training loss at last epoch: 0.686
# time t = 1009
# training loss at last epoch: 0.689
# time t = 1010
# training loss at last epoch: 0.685
# time t = 1011
# training loss at last epoch: 0.710
# time t = 1012
# training loss at last epoch: 0.690
# time t = 1013
# training loss at last epoch: 0.662
# time t = 1014
# training loss at last epoch: 0.693
# time t = 1015
# training loss at last epoch: 0.668
# time t = 1016
# training loss at last epoch: 0.663
# time t = 1017
# training loss at last epoch: 0.659
# time t = 1018
# training loss at last epoch: 0.675
# time t = 1019
# training loss at last epoch: 0.643
# time t = 1020
# training loss at last epoch: 0.658
# time t = 1021
# training loss at last epoch: 0.667
# time t = 1022
# training loss at last epoch: 0.664
# time t = 1023
# training loss at last epoch: 0.663
# time t = 1024
# training loss at last epoch: 0.673
# time t = 1025
# training loss at last epoch: 0.677
# time t = 1026
# training loss at last epoch: 0.686
# time t = 1027
# training loss at last epoch: 0.690
# time t = 1028
# training loss at last epoch: 0.698
# time t = 1029
# training loss at last epoch: 0.702
# time t = 1030
# training loss at last epoch: 0.697
# time t = 1031
# training loss at last epoch: 0.713
# time t = 1032
# training loss at last epoch: 0.703
# time t = 1033
# training loss at last epoch: 0.702
# time t = 1034
# training loss at last epoch: 0.702
# time t = 1035
# training loss at last epoch: 0.719
# time t = 1036
# training loss at last epoch: 0.683
# time t = 1037
# training loss at last epoch: 0.714
# time t = 1038
# training loss at last epoch: 0.715
# time t = 1039
# training loss at last epoch: 0.720
# time t = 1040
# training loss at last epoch: 0.687
# time t = 1041
# training loss at last epoch: 0.673
# time t = 1042
# training loss at last epoch: 0.685
# time t = 1043
# training loss at last epoch: 0.661
# time t = 1044
# training loss at last epoch: 0.667
# time t = 1045
# training loss at last epoch: 0.673
# time t = 1046
# training loss at last epoch: 0.670
# time t = 1047
# training loss at last epoch: 0.674
# time t = 1048
# training loss at last epoch: 0.680
# time t = 1049
# training loss at last epoch: 0.691
# time t = 1050
# training loss at last epoch: 0.696
# time t = 1051
# training loss at last epoch: 0.700
# time t = 1052
# training loss at last epoch: 0.708
# time t = 1053
# training loss at last epoch: 0.720
# time t = 1054
# training loss at last epoch: 0.713
# time t = 1055
# training loss at last epoch: 0.703
# time t = 1056
# training loss at last epoch: 0.697
# time t = 1057
# training loss at last epoch: 0.674
# time t = 1058
# training loss at last epoch: 0.670
# time t = 1059
# training loss at last epoch: 0.679
# time t = 1193
# training loss at last epoch: 0.707
# time t = 1194
# training loss at last epoch: 0.718
# time t = 1195
# training loss at last epoch: 0.714
# time t = 1196
# training loss at last epoch: 0.689
# time t = 1197
# training loss at last epoch: 0.722
# time t = 1198
# training loss at last epoch: 0.722
# time t = 1199
# training loss at last epoch: 0.699

# %%
# save the results
import pickle
results = {
    "prisk": prospective_risk, 
    "irisk": instant_risk
}
with open('results.pkl', 'wb') as file:
    pickle.dump(results, file)

# %% [markdown]
# Finally, we plot the instantaneous and prospecitve risks against the times $t$.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-v0_8-whitegrid")
sns.set(context='poster',
            style='ticks',
            font_scale=0.9,
            rc={'axes.grid':True,
                'grid.color':'.9',
                'grid.linewidth':0.75})
from matplotlib.lines import Line2D

fig, axes = plt.subplots(2, 1, figsize=(14, 7), sharex=True)
colors = ['#377eb8', '#e41a1c', '#4daf4a', '#984ea3']

for i, method in enumerate(methods):
    ax = axes[0]
    ax.plot(t_list, instant_risk[method], color=colors[i], lw=2.5, label=method)
    ax.set_ylabel("Instantaneous Risk")
    ax.set_yticks([0, 0.5, 1])
    ax.set_ylim([-0.05, 1.05])
    ax.set_xlim([t_list[0], t_list[-1]])

    ax = axes[1]
    ax.plot(t_list, prospective_risk[method], color=colors[i], lw=2.5)
    ax.set_ylabel("Prospective Risk")
    ax.set_yticks([0, 0.5, 1])
    ax.set_ylim([-0.05, 1.05])
    ax.set_xlim([t_list[0], t_list[-1]])

    ax.set_xlabel("Time (t)")

switch_times = np.arange(0, t_list[-1]+2, period//2)
for i in range(0, len(switch_times)-1, 2):
    for j in range(0, 2):
        ax = axes[j]
        ax.fill_betweenx([-0.1, 1.1], switch_times[i], switch_times[i+1], color='lightgray', alpha=0.2)
        
for j in range(0, 2):
    ax = axes[j]
    ax.plot(t_list, np.zeros_like(t_list), lw=2, ls='dashed', color='k', label="Bayes Risk")
axes[0].grid(visible=False)
axes[1].grid(visible=False)

legend_elements = [
    Line2D([0], [0], color='k', lw=4, ls='dashed', label='Bayes Risk'),
    Line2D([0], [0], color='#377eb8', lw=4, label='Follow-the-Leader'),
    Line2D([0], [0], color='#4daf4a', lw=4, label='Online GD'),
    Line2D([0], [0], color='#984ea3', lw=4, label='Bayesian GD'),
    Line2D([0], [0], color='#e41a1c', lw=4, label='Prospective Learner'),
]

ax = axes[0]
ax.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 0.3))
plt.show()

# %% [markdown]
# By construction, this data generating process induces a time-variant optimal decision boundary that switches every 10 time steps.
# However, follow-the-leader (FTL), online gradient descent (OGD), and Bayesian gradient descent (BDG) only output a single fixed predictor at each time $t$ for the future times,
# and as a result they fail to achieve a good prospective risk. In fact, they are not able to do better than random guessing even after observing a large amount of data.
# Notice that the instantenous risk of FTL and BGD surges when the distribution swicthes from task 1 to task 2. On other the other hand, we can see that the prospective learer achieves a good instantaneous and prospective risk as it observes more data from the process.
#
# For further details about the prospective learning framework and our experiments, we invite you to read our [paper](https://arxiv.org/pdf/2411.00109).
